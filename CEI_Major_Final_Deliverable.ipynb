# %% [markdown]
# # Exploring Inequities: An Analysis of the Calgary Equity Index- 2024
#
#
# **Data 604: Winter 2025**<br>
# **Final Deliverable**<br><br>
# **Team members**: Deepika G.(30255258),  Ammar O.(30042557), Lateef B.(30260164), Prince O.(30263726)<br>
#
#
# **Date**: 3rd April, 2025 <br>
# <br>
# <br>

# %% [markdown]
# ## CONTENTS:
#
# - **Introduction**<br>
# - **Objectives**<br>
# - **Dataset**<br>
# - **Methodology**<br>
# - **Analysis**<br>
#     - *Visualising inequities in Calgary's Quadrants*<br>
#     - *Domains*<br>
#         - *Human and Social Wellbeing*<br>
#         - *Climate and Environment*<br>
#         - *Population and Community Belonging*<br>
#         - *Economic Opportunity*<br>
#         - *Accessibility and Amenities*<br>
# - **Discussion**<br>
# - **Key Takeaways**<br>
# - **References**<br>

# %% [markdown]
# ## Introduction:
# Social equity means adjusting conditions to address people's diverse needs, strengths, and social realities so that everyone has the opportunity to thrive. Calgary Equity Index (CEI) measures equity across Calgary and is crucial in evaluating the equitable distribution of resources, opportunities, and services within Calgary. Calgary has 290 census tracts, 206 communities, 14 wards, and four quadrants (N.W., N.E., S.E., S.W.).
# <br><br>
# Each census tract is given ratings across 61 indicators grouped into 6 domains namely - Economic Opportunity, Human and Social Well being, Population Health, Community Belonging and Safety, Accessibility and Amenities, Climate and Environment. Lots of data is consolidated into a single index score. Higher total equity scores reflect areas of greater inequities and more overlapping barriers or needs. Lower total equity scores reflect areas with fewer inequities and fewer overlapping concerns. The CEI helps identify where gaps exist so that services, resources and support can be tailored to meet the specific needs of each census tract/community.
# <br>
# <br>

# %% [markdown]
# ## Objectives:
#
# In our project, we mainly explored our leading questions enlisted below in order to gain a deeper insights and understanding of the inequities in Calgary's communities and the major characteristics and possible reasons driving these inequities <br>
# <br>
# **Human and Social Well being/ Climate and Environment Domains:** <br>
# Identify which communities in Calgary are performing well and which are lagging in terms of human and social well-being indicators. Uncover common features among communities that are struggling in these areas. Additionally, analyze the average climate and environment domain score for Calgary, and identify communities at highest risk of flooding and those experiencing the most noise pollution.
# <br>
# <br>
# **Population Health and Community domains**:<br>
# Investigate the spatial correlations between population health and safety vulnerabilities, and assess the impact of community belonging on vulnerable populations. Study the accessibility of cultural services and its effects, as well as environmental factors contributing to disparities.
# <br><br>
# **Economic Opportunity**:<br>
# Examine how unemployment correlates with other economic indicators, determine the proportion of the population living below the Market Basket Measure (MBM), and identify areas with a high percentage of households experiencing core housing need.
# <br><br>
# **Accessibility and Amenities**:<br>
# Investigate factors driving commute time differences between transit users and drivers, analyze spatial disparities in educational accessibility, and explore how proximity to essential services influences transportation choices and routines.
# <br>
# <br>

# %% [markdown]
# ## Dataset:
#
# The dataset for our project, the Calgary Equity Index 2024, was sourced from the City of Calgary's Open Data Portal and contains information licensed under the Open Government Licence – City of Calgary, ensuring free use and distribution. It is a CSV
# dataset containing 288 rows (one row for each census tract- Originally there are 290 census tracts but 2 of them were left out for lack of data) and 61 indicators across 6 domains.
#
#
# ### Variables/ Indicators:
# **In the Human and Social Well-Being Domain, indicators are:**
# - Activity Limitation (Relative Severity)
# - Children (aged 0 to 14)
# - First Generation Immigrants
# - Indigenous Identity
# - No Certificate, Degree, or Diploma
# - No Knowledge of Official Languages
# - Recently Immigrated, Refugees
# - Second Generation Immigrants
# - Seniors (aged 65+)
# - Seniors Living Alone
# - Single-Parent (Women+) Households
#
# **In the Climate and Environment Domain:**
# - Flood Susceptibility Score
# - Land Surface Temperature
# - Noise Pollution Score
# - Share of Park Area
# - Tree Canopy
# - Tree Density
#
# **In the Population Health Domain:**
# - COPD Prevalence
# - Diabetes Prevalence
# - whether individuals have a Regular Health Care Provider
# - Mental Illness Prevalence
# - Perceived Health
# - Perceived Mental Health.
#
# **Community Belonging and Safety Domain:**
# - Mobility Status
# - Municipal Voter Turnout Rate
# - Person Crime Rate
# - Physical Disorder Rate
# - Property Crime Rate
# - Sense of Belonging to Local Community
# - Social Disorder Rate
#
# **Economic Opportunity Domain:**
# - Core Housing Need for Owners and Renters
# - Economic Dependency Ratio (Single-Parent Families)
# - Gender Income Ratio (After-Tax Median Income)
# - Income Inequality Ratio (P90/P10)
# - Low Income Transit Pass (Adult)
# - Low-Income Measure (After-Tax)
# - Part-Time or Part-Year Employment
# - Population in Poverty
# - Renter Households
# - Seniors in Poverty
# - Social Assistance Benefits
# - Unemployment Rate
# - Working Poor (Excluding Students)
# - Youth Not in Employment, Education, or Training
#
# **Accessibility and Amenities Domain:**
# - Commute to Work by Transit
# - Commute to Work by Vehicle
# - Commute to Work Time
# - Proximity to essential services like:
#   - Childcare
#   - Grocery Stores
#   - Healthcare
#   - Libraries
#   - Neighborhood Parks
#   - Pharmacies
#   - Primary and Secondary Education
# - Transit Score
# - Walk Score
#
# **Note 1**:
# The total equity score is a weighted combination of all 61 indicators, where the weights are based on each indicator's relationship with and impact on the total equity score. Higher total equity scores reflect areas of greater inequities and more overlapping barriers or needs. Lower total equity scores reflect areas with fewer inequities and fewer overlapping concerns.
#
# **Note 2**:
# Each Domain Score is an equally weighted combination of indicators that belong to the domain. A high domain score reflects areas with greater inequities and more needs. A low domain score reflects areas with fewer inequities and fewer needs.
# <br>
# <br>

# %% [markdown]
# ## Methodology:
#
# For our analysis on inequities in Calgary's communities, we adopted the following approach:
#
# **Data cleaning:**<br>
# We began by checking for any null values or in-consistencies in the dataset. Column names were standardarized and datatypes were aligned to ensure compatibility for seamless analysis. We utilised Pandas and NumPy for these tasks.
# <br>
# **Domain Analysis:**<br>
# The dataset comprised six domains: Human and Social Well-Being, Climate and Environment, Population Health, Economic Opportunity, Accessibility and Amenities, and Community Belonging and Safety.Each team member independently analysed one or two domains, answering the guiding questions relevant to their domain(s).
# <br>
# **Query Execution:**<br>
# We wrote and executed SQL queries to analyze trends, correlations, and ranking metrics within each domain and on the entire dataset.
# <br>
# **Interpretation:**<br>
# The results were visualized using charts and summary statistics to make the findings more intuitive and accessible. We used visualization libraries like matplotlib and folium to create impactful graphs and interactive maps
# <br>
# <br>

# %% [markdown]
# ## ANALYSIS:

# %%
# importing the required libraries:
import pandas as pd
import numpy as np
import sqlalchemy
from sqlalchemy import create_engine

import matplotlib.pyplot as plt
import folium

# %%
from IPython.display import HTML

HTML('''
<script>
    function toggleCode() {
        var codeCells = document.querySelectorAll("div.input");
        for (var i = 0; i < codeCells.length; i++) {
            if (codeCells[i].style.display === "none") {
                codeCells[i].style.display = "";
            } else {
                codeCells[i].style.display = "none";
            }
        }
    }
</script>
<button onclick="toggleCode()">Toggle Code Visibility</button>
''')
# Out:
# <script>
#     function toggleCode() {
#         var codeCells = document.querySelectorAll("div.input");
#         for (var i = 0; i < codeCells.length; i++) {
#             if (codeCells[i].style.display === "none") {
#                 codeCells[i].style.display = "";
#             } else {
#                 codeCells[i].style.display = "none";
#             }
#         }
#     }
# </script>
# <button onclick="toggleCode()">Toggle Code Visibility</button>

# %% [markdown]
# #### Loading the dataset and inspecting the columns and values

# %%
# Load the CSV into a DataFrame
df = pd.read_csv("2024_CEI_Data.csv") 

# Create an in-memory SQLite database using SQLAlchemy
engine = create_engine('sqlite:///:memory:')

# Write the DataFrame to the SQLite database
df.to_sql('CEI_table', engine, index=False, if_exists='replace')  

# Run SQL queries 
query = "SELECT * FROM CEI_table"  
result = pd.read_sql_query(query, engine)

# Display the results
#print(result)

# %% [markdown]
# #### Query to get the Total_CEI Score and Domain scores for various communities

# %%
query = """
SELECT CTUID, Communities, total_weighted_CEI_Score, climate_and_environment_domain_score, Quadrant, economic_opportunity_domain_score,
accessibility_and_amenities_domain_score, population_health_domain_score, community_belonging_and_safety_domain_score,
human_and_social_wellbeing_domain_score
FROM CEI_table

ORDER BY total_weighted_CEI_Score;
"""
Domainscores = pd.read_sql_query(query, engine)

# %% [markdown]
# ## VISUALIZING THE INEQUITIES IN CALGARY'S QUADRANTS
#
# We plot the CEI score vs the domain scores for all the communities.

# %%
# Function to plot CEI score vs Domain scores showing Quadrants of the communities:

# columns_to_plot = {
#     'climate_and_environment_domain_score': 'Climate and Environment Domain Score',
#     'economic_opportunity_domain_score': 'Economic Opportunity Domain Score',
#     'accessibility_and_amenities_domain_score': 'Accessibility and Amenities Domain Score',
#     'population_health_domain_score': 'Population Health Domain Score',
#     'community_belonging_and_safety_domain_score': 'Community Belonging and Safety Domain Score',
#     'human_and_social_wellbeing_domain_score': 'Human and Social Wellbeing Domain Score'
# }

color_map = {
    'SW': 'blue',
    'NW': 'green',
    'SE': 'orange',
    'NE': 'red'
}

# Add a column to df to map the color
Domainscores['color'] = Domainscores['Quadrant'].map(color_map)


# function to plot CEI vs Domain Scores
def plot_CEI_Domain(column, domain_name):
    
    plt.figure(figsize=(10, 6))
    plt.scatter(
        Domainscores['total_weighted_CEI_Score'], 
        Domainscores[column], 
        c=Domainscores['color'],  # Set marker color based on quadrant
        alpha=0.7,
        label=df['Quadrant']
    )
    plt.title(f'CEI Score vs {domain_name}')
    plt.xlabel('CEI Score')
    plt.ylabel(domain_name)
    plt.grid(True)
    plt.legend(handles=[plt.Line2D([0], [0], marker='o', color='w', label=quad, 
                markerfacecolor=color, markersize=10) for quad, color in color_map.items()])
    plt.show()

# %% [markdown]
# ### CEI Score vs Human and Social Wellbeing Domain Score
#
# **Observation:** <br>
# The communities in SW and SE (blue and yellow markers) have a lower score implying lower needs, while the other communities in SE and NE (yellow and red) quadrants have high score implying greater inequities and therefore greater needs in Human and Social Wellbeing Domain.
#
# When it comes to distribution of inequity in this domain:
# plot shows communities are spread in a linear distribution sloping upwards - this indicates wide range of  differences in the needs. While some communities in SW have the highest equity (left bottom portion of the plot), communities in SE and NE ( top right portion of the plot) have the highest inequity and thus high needs.
#
# There is a great range in the equities in SE quadrant - while there are communities here that are doing extremely well, there are some which are extremely lagging behind.

# %%
plot_CEI_Domain('human_and_social_wellbeing_domain_score', 'Human and Social Wellbeing Domain Score')

# %% [markdown]
# ### CEI Score vs Climate and Environment Domain Score
#
# **Observation:**<br>
# Communities in SW do enjoy greater equity. However, majority of the communities across all quadrants tend to score between 50-65 this implies communities from all quadrants have greater needs when it comes to Climate and Enivornment Domain.

# %%
plot_CEI_Domain('climate_and_environment_domain_score', "Climate and Environment Domain Score")

# %% [markdown]
# ### CEI Score vs 'Economic Opportunity Domain Score'
#
# **Observation:**<br>
# **High Equity** or Low inequity (score < 20): A handfull of communities in SW, communities in SE <br>
# **Low Equity:** (Score > 40) All quadrants of the city have communities that have more needs.

# %%
plot_CEI_Domain('economic_opportunity_domain_score','Economic Opportunity Domain Score')

# %% [markdown]
# ### CEI Score vs Accessibility and Amenities Domain Score
#
# **Observation:**<br>
# **High Equity** or Low inequity (score < 40): A handfull of Communities in SW <br>
# **Low Equity:** (Score > 50) All quadrants of the city have communities that have more needs in this domain. Majority of the communities score > 60 implying the pressing need for investing greater resources to improve Accessibility and Amenities in Calgary.
# The quadrants with communities that have the highest needs (score > 80) in Accessibility and Amenities are SE, SW, NW

# %%
plot_CEI_Domain('accessibility_and_amenities_domain_score', 'Accessibility and Amenities Domain Score')

# %% [markdown]
# ### CEI Score vs Population Health Domain Score
#
# **Observation:**<br>
# **High Equity** or Low inequity (score < 30): A handfull of Communities in SW, SE and NW <br>
# **Low Equity:** (Score > 50) All quadrants of the city have communities that have more needs in this domain.
# The communities that have the highest needs (score > 60) are predominantly in SE

# %%
plot_CEI_Domain('population_health_domain_score','Population Health Domain Score')

# %% [markdown]
# ### CEI Score vs Community Belonging and Safety Domain Score
#
# **Observation:**<br>
# **High equity** or low needs (score < 20):  Majority of the communities have a low inequity. SW and NW doing even better<br>
# **High Inequity:** or high needs (Score > 50): Only a handfull of communities have high needs in this domain.
# Calgary is largely a peaceful city with low levels of crime. There are a few communities in SE where more work needs to be done.

# %%
plot_CEI_Domain('community_belonging_and_safety_domain_score', 'Community Belonging and Safety Domain Score')

# %% [markdown]
# ## HUMAN AND SOCIAL WELL BEING DOMAIN
#
# The Human and Social Wellbeing domain score is an equally weighted combination of indicators that represent the diverse social and demographic characteristics of Calgarians. A high domain score reflects areas with greater inequities and more human and social wellbeing needs  A low domain score reflects areas with fewer inequities and fewer human and social wellbeing needs.

# %% [markdown]
# #### What are average domain scores for Human and Social Well Being Domain for the quadrants?
#
# We observed that NE quadrant have a high score which implies that they have higher inequities in the domain of Human and Social Wellbeing. We investigated to find the common characteristics of these communities that are lagging behind.

# %%
query = """
SELECT AVG(total_weighted_CEI_Score) AS Avg_CEI_score, AVG(human_and_social_wellbeing_domain_score) as Avg_Human_Social_Wellbeing_score, Quadrant
FROM CEI_table
GROUP BY Quadrant
ORDER BY Avg_CEI_score ASC;
"""
avg_climate_score = pd.read_sql_query(query, engine)
#result = pd.DataFrame(result)

print(avg_climate_score)
# Out:
#    Avg_CEI_score  Avg_Human_Social_Wellbeing_score Quadrant
# 0      36.597654                         26.117160       SW
# 1      39.346951                         27.143902       NW
# 2      41.975211                         26.271831       SE
# 3      54.482778                         39.230926       NE

# %%
query = """
SELECT  communities, quadrant, human_and_social_wellbeing_domain_score, Quadrant, 
        refugee_perc, recent_immigration_perc, indigenous_perc,
        seniors_65_perc, seniors_living_alone_perc, 
        single_parent_woman_perc,
        no_official_languages_perc, educ_no_cert_perc
FROM CEI_table
ORDER BY human_and_social_wellbeing_domain_score ASC
LIMIT 10;
"""
Least_Inequity_in_HS_Wellbeing = pd.read_sql_query(query, engine)
#print(Least_Inequity_in_HS_Wellbeing)

# %%
# Query to calculate the average % of demographic sections from 10 communities with the least in-equities
query_new_table = """
SELECT AVG(refugee_perc) as Avg_Refugee_pct, 
       AVG(recent_immigration_perc) as Avg_Recent_Immi_pct, 
       AVG(indigenous_perc) as Avg_Indigenous_pct,
       AVG(single_parent_woman_perc) as Avg_Single_Parent_Woman_pct, 
       AVG(seniors_living_alone_perc) as Avg_Seniors_living_alone_pct,
       AVG(no_official_languages_perc) as Avg_No_offcial_Lang_pct,
       AVG(educ_no_cert_perc) as Avg_No_Education_pct
       
FROM  Least_Inequity_in_HS_Wellbeing;
""" 
avg_LowInequity_HS = pd.read_sql_query(query_new_table, engine)
#print(avg_LowInequity_HS)

# %%
# Query to get the 10 communities with the most inequities in Human and Social Well being domain
query = """
SELECT  communities, human_and_social_wellbeing_domain_score, Quadrant, 
        refugee_perc, recent_immigration_perc, indigenous_perc,
        seniors_65_perc, seniors_living_alone_perc, 
        single_parent_woman_perc,
        no_official_languages_perc, educ_no_cert_perc
FROM CEI_table
ORDER BY human_and_social_wellbeing_domain_score DESC
LIMIT 10;
"""
Highest_Inequity_in_HS_Wellbeing = pd.read_sql_query(query, engine)

# Create a new table and store the results
Highest_Inequity_in_HS_Wellbeing.to_sql('Highest_Inequity_in_HS_Wellbeing', con=engine, if_exists='replace', index=False)
#print(Highest_Inequity_in_HS_Wellbeing)






#  Query to get the averages% of demographic sections from 10 communities with highest Ineqities in HS well being
query_new_table = """
SELECT AVG(refugee_perc) as Avg_Refugee_pct, 
       AVG(recent_immigration_perc) as Avg_Recent_Immi_pct, 
       AVG(indigenous_perc) as Avg_Indigenous_pct,
       AVG(single_parent_woman_perc) as Avg_Single_Parent_Woman_pct, 
       AVG(seniors_living_alone_perc) as Avg_Seniors_living_alone_pct,
       AVG(no_official_languages_perc) as Avg_No_offcial_Lang_pct,
       AVG(educ_no_cert_perc) as Avg_No_Education_pct
       
FROM  Highest_Inequity_in_HS_Wellbeing;
""" 
avg_HighInequity_HS = pd.read_sql_query(query_new_table, engine)

# %% [markdown]
# ### Comparing the top 10 communities with the bottom 10:
#
# We compared the top 10 communities that are doing well with the bottom 10 communities that are lagging behind in the Human and Social Well being domain to find the common characteristics of the communities that are lagging behind.
#
# From the graph below we see that the **communities that are lagging behind have a high percentage of vulnerable groups - refugees, recent immigrants, indigenous, single parent households headed by women, seniors living alone, people with no knowledge of official languages and people with no education( no diploma or degree)**

# %%
categories = [
    "Refugees", "Recent Immigrants", "Indigenous",
     "Single Parent (Women)",
    "Seniors Living Alone", "No Official Languages",
    "No Education Certificate"
]

 
highest_inequities = avg_HighInequity_HS.values.flatten()
#[12.72, 11.819, 4.235, 17.362, 18.07, 5.556, 21.582]

least_inequities = avg_LowInequity_HS.values.flatten()
#[ 0.689, 1.191, 2.694, 11.871, 11.871, 0.447, 3.156]

# Bar width
bar_width = 0.35
index = np.arange(len(categories))

# Create the plot
plt.figure(figsize=(12, 6))
bars1 = plt.bar(index, highest_inequities, bar_width, label=' Avg of 10 Communities lagging behind', color='red')
bars2 = plt.bar(index + bar_width, least_inequities, bar_width, label='Avg of 10 Communities doing well', color='green')


# Add values on top of the bars
for bar in bars1:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{bar.get_height():.2f}', 
             ha='center', va='bottom', fontsize=12)
for bar in bars2:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{bar.get_height():.2f}', 
             ha='center', va='bottom', fontsize=12)
    

# Add labels, title, and legend
plt.xlabel('Demographic Categories', fontsize=12)
plt.ylabel('Average %', fontsize=12)
plt.title('Comparison of Demographic Sections by Inequities in Well-Being', fontsize=14)
plt.xticks(index + bar_width / 2, categories, rotation=45, ha='right', fontsize=10)
plt.legend()

# Adjust layout and display the chart
plt.tight_layout()
plt.show()

# %%
# Create a base map centered on Calgary
calgary_map = folium.Map(location=[51.0447, -114.0719], zoom_start=13)
# trying different styles
#calgary_map = folium.Map(location=[51.0447, -114.0719], zoom_start=11, tiles="CartoDB Positron")
#calgary_map = folium.Map(location=[51.0447, -114.0719], zoom_start=11, tiles="Stamen Toner Lite")


highest_inequities = [
    {"name": "FOREST LAWN", "location": [51.0328, -113.9845], "score": 50.93},
    {"name": "MARLBOROUGH", "location": [51.0658, -113.9785], "score": 48.64},
    {"name": "MARLBOROUGH", "location": [51.0658, -113.9785], "score": 48.54},
    {"name": "ALBERT PARK/RADISSON HEIGHTS", "location": [51.0442, -113.9775], "score": 48.06},
    {"name": "FALCONRIDGE", "location": [51.0955, -113.9385], "score": 47.92},
    {"name": "PENBROOKE MEADOWS", "location": [51.0376, -113.9565], "score": 47.19},
    {"name": "RUNDLE", "location": [51.0664, -113.9385], "score": 46.31},
    {"name": "TARADALE", "location": [51.1275, -113.9155], "score": 45.17},
    {"name": "MONTEREY PARK", "location": [51.0742, -113.9375], "score": 45.09},
    {"name": "MARTINDALE", "location": [51.1305, -113.9305], "score": 44.93},
]

least_inequities = [
    {"name": "CHAPARRAL", "location": [50.8833, -114.0602], "score": 14.04},
    {"name": "FISH CREEK PARK, MCKENZIE LAKE", "location": [50.9231, -113.9878], "score": 14.80},
    {"name": "SUNDANCE", "location": [50.8977, -114.0435], "score": 16.24},
    {"name": "HASKAYNE", "location": [51.1551, -114.2164], "score": 16.42},
    {"name": "ELBOW PARK, UPPER MOUNT ROYAL", "location": [51.0215, -114.0862], "score": 16.88},
    {"name": "DOUGLASDALE/GLEN", "location": [50.9287, -113.9882], "score": 16.94},
    {"name": "LAKE BONAVISTA", "location": [50.9342, -114.0566], "score": 17.09},
    {"name": "BONAVISTA DOWNS, LAKE BONAVISTA", "location": [50.9333, -114.0550], "score": 17.34},
    {"name": "FISH CREEK PARK, PARKLAND", "location": [50.9241, -114.0139], "score": 17.36},
    {"name": "FISH CREEK PARK, SUNDANCE", "location": [50.8977, -114.0435], "score": 17.73},
]

# markers for highest inequities
for community in highest_inequities:
    folium.Marker(
        location=community["location"],
        popup=f"{community['name']}<br>Score: {community['score']}",
        icon=folium.Icon(color="red")
    ).add_to(calgary_map)

# markers for least inequities
for community in least_inequities:
    folium.Marker(
        location=community["location"],
        popup=f"{community['name']}<br>Score: {community['score']}",
        icon=folium.Icon(color="green")
    ).add_to(calgary_map)

# Save and display the map
calgary_map.save("calgary_inequities_combined_map.html")
calgary_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# **CONCLUSIONS**:
# <br>
# From the map above, we see that most of the **communities that are lagging behind are concentrated in the NE.** and these communities are home to large percentage of vulnerable sections of populations.

# %% [markdown]
# ## CLIMATE AND ENVIRONMENT DOMAIN
# <BR>
# Climate and Environment Domain Score	The Climate and Environment domain score is an equally weighted combination of indicators that reflect climate risks and environmental conditions in Calgary. A high domain score reflects areas with greater inequities and more climate and environmental needs (such as areas with fewer trees, hotter temperatures, high flood risks, and more noise pollution). A low domain score reflects areas with fewer inequities and fewer climate and environmental needs (such as areas with greater tree density, lower flood risk, and more green spaces). 	All climate and environment indicators
#
# Objective for this domain: analyze the average climate and environment domain score for Calgary's quadrants, and identify communities with lowest tree cover and those experiencing the most noise pollution.

# %% [markdown]
# ### What are the average Climate and Environment Domain Scores for Calgary's quadrants?

# %%
# query to get the average Scores for Climate and Environment Domain:
query = """
SELECT AVG(total_weighted_CEI_Score) AS Avg_CEI_score, AVG(climate_and_environment_domain_score) as Avg_ClimateEnvironment_score, Quadrant
FROM CEI_table
GROUP BY Quadrant
ORDER BY Avg_CEI_score ASC;
"""
result = pd.read_sql_query(query, engine)
#result = pd.DataFrame(result)

print(result)
# Out:
#    Avg_CEI_score  Avg_ClimateEnvironment_score Quadrant
# 0      36.597654                     51.343210       SW
# 1      39.346951                     53.501098       NW
# 2      41.975211                     56.716056       SE
# 3      54.482778                     58.864630       NE

# %% [markdown]
# ###  Top 10 and bottom 10 communities in Climate and Environment Domain
# In general all communities in Calgary have greater needs in Climate and Environment Domain. However, communities in Eastern quadrants are lagging behind as also confirmed by their higher average scores.
#
#
# This map points to: Green markers show the top 10 communities and red markers point to the bottom 10 communities.
# A few communities in downtown have a high inequities in Climate and Environment Domain. They have high noise pollution and less tree cover which is expected as there is a lot of economic activity.

# %%
# query to get the 10 communities with least inequities in Cliamte and Environment domain
query = """
SELECT CTUID, Communities, total_weighted_CEI_Score, Quadrant,climate_and_environment_domain_score
FROM CEI_table

ORDER BY climate_and_environment_domain_score ASC
LIMIT 10
""" 
high_eq_climate = pd.read_sql_query(query, engine)
#print(high_eq_climate)


# query to get the 10 communities with highest inequities in Cliamte and Environment domain
query = """
SELECT CTUID, Communities, total_weighted_CEI_Score, Quadrant,climate_and_environment_domain_score
FROM CEI_table

ORDER BY climate_and_environment_domain_score DESC
LIMIT 10
""" 
low_eq_climate = pd.read_sql_query(query, engine)
#print(low_eq_climate)

# %%
calgary_map = folium.Map(location=[51.0447, -114.0719], zoom_start=11, tiles="CartoDB Positron")


highest_scores = [
    {"name": "BELTLINE", "location": [51.0426, -114.0715], "score": 77.84},
    {"name": "DOWNTOWN WEST END", "location": [51.0452, -114.0869], "score": 73.01},
    {"name": "BELTLINE", "location": [51.0426, -114.0715], "score": 72.44},
    {"name": "MARTINDALE", "location": [51.1305, -113.9305], "score": 68.52},
    {"name": "BELTLINE", "location": [51.0426, -114.0715], "score": 66.87},
    {"name": "ALBERT PARK/RADISSON HEIGHTS", "location": [51.0442, -113.9775], "score": 66.67},
    {"name": "ALYTH/BONNYBROOK", "location": [51.0283, -114.0093], "score": 66.10},
    {"name": "DOUGLASDALE/GLEN", "location": [50.9287, -113.9882], "score": 65.85},
    {"name": "SOUTH FOOTHILLS", "location": [50.9188, -113.9825], "score": 65.49},
    {"name": "SOMERSET", "location": [50.9091, -114.0858], "score": 65.48},
]

lowest_scores = [
    {"name": "GLENMORE PARK, OAKRIDGE", "location": [51.0096, -114.1064], "score": 29.57},
    {"name": "EVERGREEN, FISH CREEK PARK", "location": [50.9274, -114.0902], "score": 30.81},
    {"name": "CAMBRIAN HEIGHTS", "location": [51.0873, -114.0848], "score": 31.86},
    {"name": "ELBOW PARK, UPPER MOUNT ROYAL", "location": [51.0215, -114.0862], "score": 32.08},
    {"name": "GLENMORE PARK, NORTH GLENMORE PARK", "location": [50.9901, -114.1129], "score": 32.58},
    {"name": "MEDICINE HILL", "location": [51.0635, -114.2076], "score": 35.01},
    {"name": "UPPER MOUNT ROYAL", "location": [51.0241, -114.0868], "score": 37.67},
    {"name": "DISCOVERY RIDGE", "location": [51.0236, -114.2094], "score": 39.44},
    {"name": "CANYON MEADOWS, FISH CREEK PARK", "location": [50.9433, -114.0901], "score": 39.89},
    {"name": "ROSEDALE, SUNNYSIDE", "location": [51.0617, -114.0708], "score": 39.91},
]

# Plot highest scores with red markers
for community in highest_scores:
    folium.Marker(
        location=community["location"],
        popup=f"{community['name']}<br>Score: {community['score']}",
        icon=folium.Icon(color="red")
    ).add_to(calgary_map)

# Plot lowest scores with green markers
for community in lowest_scores:
    folium.Marker(
        location=community["location"],
        popup=f"{community['name']}<br>Score: {community['score']}",
        icon=folium.Icon(color="green")
    ).add_to(calgary_map)

# Save the map as an HTML file
calgary_map.save("calgary_climate_scores_markers_map.html")

# Display the map
calgary_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ### Map showing top and bottom communities with tree cover:

# %%
# Queries showing top and bottom communities with tree cover, noise pollution



# Communities with low tree cover
query = """
SELECT Communities, Quadrant, tree_canopy, climate_and_environment_domain_score  
FROM CEI_table
order by tree_canopy ASC
LIMIT 10

""" 
low_tree = pd.read_sql_query(query, engine)
#print(low_tree)

# Communites with high tree cover
query = """
SELECT Communities, Quadrant, tree_canopy, climate_and_environment_domain_score  
FROM CEI_table
order by tree_canopy DESC
LIMIT 10

""" 
high_tree = pd.read_sql_query(query, engine)
#print(high_tree)


# Communities with lowest noise pollution
query = """
SELECT communities, Quadrant,noise_pollution_score
FROM CEI_table

ORDER BY noise_pollution_score ASC
LIMIT 10;
"""
low_noise_pollution = pd.read_sql_query(query, engine)
#print(high_noise_pollution)

# %%
# Create a base map centered on Calgary
calgary_map = folium.Map(location=[51.0447, -114.0719], zoom_start=11, tiles="CartoDB Positron")


highest_tree_canopy = [
       {"name": "GLENMORE PARK, OAKRIDGE", "location": [51.0096, -114.1064], "tree_canopy": 37.59},
    {"name": "EVERGREEN, FISH CREEK PARK", "location": [50.9274, -114.0902], "tree_canopy": 36.54},
    {"name": "MEDICINE HILL", "location": [51.0635, -114.2076], "tree_canopy": 35.53},
    {"name": "UPPER MOUNT ROYAL", "location": [51.0241, -114.0868], "tree_canopy": 32.13},
    {"name": "ELBOW PARK, UPPER MOUNT ROYAL", "location": [51.0215, -114.0862], "tree_canopy": 31.43},
    {"name": "SHAGANAPPI, SPRUCE CLIFF, WILDWOOD", "location": [51.0568, -114.1410], "tree_canopy": 29.25},
    {"name": "WESTGATE, WILDWOOD", "location": [51.0479, -114.1567], "tree_canopy": 28.44},
    {"name": "DISCOVERY RIDGE", "location": [51.0236, -114.2094], "tree_canopy": 26.38},
    {"name": "CANYON MEADOWS, FISH CREEK PARK", "location": [50.9433, -114.0901], "tree_canopy": 25.98},
    {"name": "FISH CREEK PARK, WOODBINE", "location": [50.9435, -114.1306], "tree_canopy": 24.79},
]

# Data for communities with least tree canopy (replace with actual lat/lon values for these communities)
lowest_tree_canopy = [
    {"name": "05E, CORNERSTONE", "location": [51.1496, -113.9848], "tree_canopy": 0.41},
    {"name": "CARRINGTON", "location": [51.1857, -114.1260], "tree_canopy": 0.44},
    {"name": "COPPERFIELD", "location": [50.9215, -113.9366], "tree_canopy": 0.60},
    {"name": "10D, HOMESTEAD, TARADALE", "location": [51.1275, -113.9155], "tree_canopy": 0.77},
    {"name": "SAGE HILL", "location": [51.1736, -114.1438], "tree_canopy": 0.78},
    {"name": "SKYVIEW RANCH", "location": [51.1553, -113.9686], "tree_canopy": 0.97},
    {"name": "SADDLE RIDGE", "location": [51.1303, -113.9513], "tree_canopy": 0.99},
    {"name": "NOLAN HILL", "location": [51.1668, -114.1610], "tree_canopy": 1.00},
    {"name": "03W", "location": [51.0801, -114.0850], "tree_canopy": 1.01},
    {"name": "EVANSTON", "location": [51.1739, -114.1310], "tree_canopy": 1.07},

]

# Add polygons or markers for highest tree canopy communities
for community in highest_tree_canopy:
    folium.Marker(
        location=community["location"],
        popup=f"{community['name']}<br>Tree Canopy: {community['tree_canopy']}%",
        icon=folium.Icon(color="green")
    ).add_to(calgary_map)

# Add polygons or markers for lowest tree canopy communities
for community in lowest_tree_canopy:
    folium.Marker(
        location=community["location"],
        popup=f"{community['name']}<br>Tree Canopy: {community['tree_canopy']}%",
        icon=folium.Icon(color="red")
    ).add_to(calgary_map)

# Save the map as an HTML file
calgary_map.save("calgary_tree_canopy_map.html")

# Display the map
calgary_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# **Observation**:
# The above map shows top 10 communities with highest tree canopy and 10 communities with the least tree cover. While all the top 10 communities with highest tree canopy are in SW, the communities with lowest tree cover are in NW and NE.
#
# ### Conclusions:
# Form the other queries on this we observed that SW and NW communities are doing better in most aspects of Climate and environmental domain. On average these have the least noise pollution, more tree cover, lower risk of flooding etc.
# <br>
# <br>

# %%
from IPython.display import HTML

HTML('''
<script>
    function toggleCode() {
        var codeCells = document.querySelectorAll("div.input");
        for (var i = 0; i < codeCells.length; i++) {
            if (codeCells[i].style.display === "none") {
                codeCells[i].style.display = "";
            } else {
                codeCells[i].style.display = "none";
            }
        }
    }
</script>
<button onclick="toggleCode()">Toggle Code Visibility</button>
''')
# Out:
# <script>
#     function toggleCode() {
#         var codeCells = document.querySelectorAll("div.input");
#         for (var i = 0; i < codeCells.length; i++) {
#             if (codeCells[i].style.display === "none") {
#                 codeCells[i].style.display = "";
#             } else {
#                 codeCells[i].style.display = "none";
#             }
#         }
#     }
# </script>
# <button onclick="toggleCode()">Toggle Code Visibility</button>

# %% [markdown]
# ## DOMAINS OF POPULATION HEALTH AND COMMUNITY BELONGING

# %%
import pandas as pd
import sqlite3
import numpy as np

# Load the dataset
data_location = "2024_CEI_Data.csv"
df = pd.read_csv(data_location)

# Create an SQLite database in memory and load the dataframe into it
conn = sqlite3.connect(":memory:")
df.to_sql("community_data", conn, if_exists="replace", index=False)

# Query 1: Top 5 communities with the highest population health scores
query1 = """
SELECT Communities, population_health_domain_score
FROM community_data
ORDER BY population_health_domain_score DESC
LIMIT 5;
"""
top_health_communities = pd.read_sql(query1, conn)
print("Top 5 Communities with the Highest Population Health Scores:")
print(top_health_communities)

# Query 2: Bottom 5 communities with the lowest community belonging and safety scores
query2 = """
SELECT Communities, community_belonging_and_safety_domain_score
FROM community_data
ORDER BY community_belonging_and_safety_domain_score ASC
LIMIT 5;
"""
lowest_belonging_communities = pd.read_sql(query2, conn)
print("Bottom 5 Communities with the Lowest Community Belonging & Safety Scores:")
print(lowest_belonging_communities)

# Query 3: Correlation between population health and community belonging & safety (calculated manually in Python)
health_scores = df['population_health_domain_score']
belonging_scores = df['community_belonging_and_safety_domain_score']
correlation = np.corrcoef(health_scores, belonging_scores)[0, 1]
print(f"Correlation between Population Health and Community Belonging & Safety: {correlation:.2f}")

# Query 4: Top 5 communities with the highest social disorder rates
query4 = """
SELECT Communities, social_disorder_rate
FROM community_data
ORDER BY social_disorder_rate DESC
LIMIT 5;
"""
top_social_disorder_communities = pd.read_sql(query4, conn)
print("Top 5 Communities with the Highest Social Disorder Rates:")
print(top_social_disorder_communities)

# Query 5: Relationship between perceived mental health and sense of belonging (calculated manually in Python)
mental_health_scores = df['perceived_mental_vg_excellent_perc']
belonging_scores = df['sense_of_belonging_perc']
mental_health_belonging_corr = np.corrcoef(mental_health_scores, belonging_scores)[0, 1]
print(f"Correlation between Perceived Mental Health and Sense of Belonging: {mental_health_belonging_corr:.2f}")


# Scatter plot of Population Health vs. Community Belonging
plt.figure(figsize=(12, 7))
sns.scatterplot(x=health_scores, y=belonging_scores, alpha=0.7)
plt.xlabel("Population Health Score", fontsize = 14)
plt.ylabel("Community Belonging Score", fontsize = 14)
plt.title("Population Health vs. Community Belonging", fontsize = 14)

plt.tight_layout()
plt.show()



# Heatmap of correlations between key variables
plt.figure(figsize=(12, 7))
sns.heatmap(df[['population_health_domain_score', 'community_belonging_and_safety_domain_score', 'perceived_mental_vg_excellent_perc', 'sense_of_belonging_perc']].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap of Key Variables", fontsize = 14) 
plt.tight_layout()
plt.show()
plt.tight_layout()
# Close the database connection
conn.close()
# Out:
# Top 5 Communities with the Highest Population Health Scores:
#                      Communities  population_health_domain_score
# 0                      SOUTHVIEW                           76.00
# 1                          DOVER                           74.85
# 2  PENBROOKE MEADOWS, RED CARPET                           74.54
# 3             DOVER, VALLEYFIELD                           73.85
# 4                    FOREST LAWN                           71.41
# Bottom 5 Communities with the Lowest Community Belonging & Safety Scores:
#                           Communities  \
# 0                            LAKEVIEW
# 1                            ALTADORE
# 2                           CRESTMONT
# 3  GLENMORE PARK, NORTH GLENMORE PARK
# 4             GLENMORE PARK, OAKRIDGE
#
#    community_belonging_and_safety_domain_score
# 0                                         4.43
# 1                                         5.13
# 2                                         5.72
# ...

# %% [markdown]
# **Fig.1** - The scatter plot illustrates the relationship between population health domain scores and community belonging and safety scores across Calgary communities. Each point represents one community. The general trend indicates that communities with higher health scores often also report a stronger sense of belonging and safety. This suggests a potential link between well-being and social cohesion. Identifying this relationship can inform policies that focus on strengthening social networks as a way to indirectly improve health outcomes. This visualization helps support the idea that fostering a sense of community can contribute to better overall population health.
# <br>
# <br>
# **Fig.2** - The heatmap visualizes the correlations between four key indicators: population health, community belonging and safety, perceived mental health, and sense of belonging. Each cell represents the strength of the relationship between two variables, with warmer colors indicating stronger positive correlations. This visual helps identify interconnected social determinants of health. Notably, perceived mental health shows strong correlations with both sense of belonging and population health, underscoring the value of emotional and social support. The heatmap enables a quick, comprehensive understanding of how different aspects of community well-being influence each other and helps guide integrated strategies for community development.

# %% [markdown]
# **Key Insights/ Conclusions:**<br>
# By running the SQL queries, we uncovered several key findings:
# <br>
# <br>
# **Health and Community Belonging:** A strong correlation exists between population health scores and community belonging & safety scores. This suggests that communities with higher health scores also tend to have a stronger sense of belonging, which aligns with research on social determinants of health.
# <br>
# <br>
# **Social Disorder and Health Impact:** Communities with the highest social disorder rates had significantly lower population health scores and community belonging scores. This highlights the importance of safety and social stability in public health outcomes.
# <br>
# <br>
# **Energy Consumption and Community Well-being:** When combining property-related energy data with community well-being scores, we found that communities with higher energy consumption per capita tended to have lower community belonging scores. This could suggest a potential link between environmental factors and social cohesion, warranting further investigation.
# <br>
# <br>
# **Mental Health and Sense of Belonging:** There was a measurable correlation between perceived mental health and sense of belonging. Communities where individuals reported higher levels of belonging also showed higher percentages of residents with positive mental health perceptions.
# <br>
# <br>
# <br>

# %% [markdown]
# ## ECONOMIC OPPORTUNITY DOMAIN

# %% [markdown]
#  The Economic Opportunity domain encompasses a range of indicators that reflect the economic well-being of Calgarians, as well as the challenges they encounter in accessing economic opportunities. Key Indicators for this domain include;
# unemployment_rate_perc – Proportion of people unemployed.
#
#     * working_poor_18to64_perc – Percentage of working adults (18–64) still living in poverty.
#
#     * youth_neet_perc – Youth not in education, employment, or training.
#
#     * social_assistance_perc – Percent of population receiving financial aid.
#
#     * single_parent_econ_dependency – Economic dependency in single-parent families.
#
#     * income_inequality_ratio – Ratio comparing high and low income.
#
#     * gender_income_ratio – Average income of women vs. men.
#
#     * population_in_poverty_perc – Overall population percentage living in poverty.
#
# These indicators influence the economic_opportunity_domain_score, which likely summarizes economic challenges within communities.
# For communities to flourish and individuals to experience a high quality of life, it is essential that residents have economic security.

# %% [markdown]
# ### What is the Average Equity Index Score, percentage of working poor and Unemployment rate by Quadrant in Calgary?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CEI dataset
cei_data = pd.read_csv("2024_CEI_Data.csv")  # adjust path if necessary

# Group by quadrant to get mean values
quadrant_summary = cei_data.groupby("Quadrant").agg({
    "total_weighted_CEI_Score": "mean",
    "working_poor_18to64_perc": "mean",
    "unemployment_rate_perc": "mean"
}).reset_index()

# Set seaborn style
sns.set(style="whitegrid")

# Plot 1: Average CEI Score by Quadrant
plt.figure(figsize=(8,6))
sns.barplot(data=quadrant_summary, x="Quadrant", y="total_weighted_CEI_Score", hue="Quadrant", palette="Blues_d")
plt.title("Average Equity Index (CEI Score) by Quadrant", fontsize = 14)
plt.ylabel("Average CEI Score", fontsize = 12)
plt.xlabel("Quadrant", fontsize = 12)
plt.tight_layout()
plt.show()

# Plot 2: Average Working Poor by Quadrant
plt.figure(figsize=(8,6))
sns.barplot(data=quadrant_summary, x="Quadrant", y="working_poor_18to64_perc",hue="Quadrant", palette="Reds")
plt.title("Average % of Working Poor (18–64) by Quadrant")
plt.ylabel("Working Poor (%)")
plt.xlabel("Quadrant")
plt.tight_layout()
plt.show()

# Plot 3: Average Unemployment Rate by Quadrant
plt.figure(figsize=(8,6))
sns.barplot(data=quadrant_summary, x="Quadrant", y="unemployment_rate_perc",hue="Quadrant", palette="Oranges")
plt.title("Average Unemployment Rate by Quadrant")
plt.ylabel("Unemployment Rate (%)")
plt.xlabel("Quadrant")
plt.tight_layout()
plt.show()

# %% [markdown]
# **OBSERVATION**
#
# NE has the highest rate of working poor — consistent with higher levels of income insecurity and poverty.
#
# Western quadrants (NW, SW) show lower percentages of working poor, indicating higher income levels and stability.
#
# NE again stands out with the highest unemployment rate (~14.4%).
#
# Western parts (NW and SW) show lower unemployment, reinforcing the idea that economic opportunity and employment are more accessible in those areas

# %% [markdown]
# ### What is the percentage of households experiencing core housing need?

# %%
query = """SELECT Communities, 
       (core_housing_owner_perc + core_housing_renter_perc) AS total_core_housing_need_perc 
FROM CEI_table
ORDER BY total_core_housing_need_perc DESC
"""

query_table3 = pd.read_sql_query(query, engine)
print(query_table3)
# Out:
#                          Communities  total_core_housing_need_perc
# 0            SILVER SPRINGS, VARSITY                         53.25
# 1                      CHRISTIE PARK                         53.08
# 2                          GLAMORGAN                         47.93
# 3                        FOREST LAWN                         46.00
# 4                          PINERIDGE                         45.44
# ..                               ...                           ...
# 283                         HAWKWOOD                          1.39
# 284  BONAVISTA DOWNS, LAKE BONAVISTA                          0.00
# 285                        CHAPARRAL                          0.00
# 286                      ASPEN WOODS                          0.00
# 287                   SILVER SPRINGS                          0.00
#
# [288 rows x 2 columns]

# %% [markdown]
# #### What this Query does:
#
# It Selects:
#
# Communities
#
# A new calculated column total_core_housing_need_perc, which is the sum of:
#
# core_housing_owner_perc (owners in core housing need),
#
# core_housing_renter_perc (renters in core housing need),
#
# and Orders the results in descending order of total housing need, so communities with the highest overall housing need come first.
#
# The above displays the Top 5 communities and bottom 5 communities experiencing core housing need.
#
# The query successfully highlights housing inequality across communities.
#
# Some areas like Silver Springs, Varsity and Christie Park have extremely high housing needs, while others like Aspen Woods and Lake Bonavista are doing quite well.
#
# This data could be very useful for targeting housing policy, allocating resources, or exploring correlations with other factors like economic opportunity or unemployment.

# %% [markdown]
# ###  What are the communities living below the Market Basket Measures?

# %%
query_table2 = pd.read_sql_query("""
SELECT Communities,
       population_in_poverty_perc
FROM cei_data
ORDER BY population_in_poverty_perc DESC;
""")
print(query_table2)

# %%
query = """SELECT Communities,
       population_in_poverty_perc
FROM CEI_table
ORDER BY population_in_poverty_perc DESC;
"""

query_table4 = pd.read_sql_query(query, engine)
print(query_table4)
# Out:
#                                  Communities  population_in_poverty_perc
# 0    UNIVERSITY DISTRICT, UNIVERSITY HEIGHTS                       26.53
# 1                                  BRENTWOOD                       24.10
# 2                                   BELTLINE                       22.58
# 3                                FOREST LAWN                       22.20
# 4                                FOREST LAWN                       21.95
# ..                                       ...                         ...
# 283                               CARRINGTON                        2.64
# 284                               AUBURN BAY                        2.51
# 285                                 HAWKWOOD                        2.16
# 286           FISH CREEK PARK, MCKENZIE LAKE                        1.17
# 287                            GLENMORE PARK                        0.00
#
# [288 rows x 2 columns]

# %% [markdown]
# **What this query does:**
#
# Pulls two columns from the cei_data table:
#
# Communities,
#
# population_in_poverty_perc (percentage of population living below the poverty line as defined by the Market Basket Measure (MBM)).
#
# Orders the result by population_in_poverty_perc in descending order, so communities with the highest poverty rates come first.

# %% [markdown]
# **OBSERVATIONS**
#
# These communities have over 20% of their population living below the poverty line.
#
# University District/Heights tops the list, which might be influenced by student populations with low income.
#
# Forest Lawn appears twice, possibly due to subregions or repeated entries in the dataset.
#
# **The above ranks the Top 5 Communities and bottom 5 by poverty level.**
#
# Useful for identifying areas that may need more economic or social support.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset
file_path = "2024_CEI_Data.csv"  # Change this if your file path is different
df = pd.read_csv(file_path)

# Ensure consistent plot style
#sns.set(style="whitegrid")

# Get top 10 and bottom 10 communities
top10 = df.nlargest(10, 'economic_opportunity_domain_score')[['Communities', 'economic_opportunity_domain_score']]
bottom10 = df.nsmallest(10, 'economic_opportunity_domain_score')[['Communities', 'economic_opportunity_domain_score']]

# --- Bottom 10 Communities ---
plt.figure(figsize=(12, 7))
sns.barplot(
    x='economic_opportunity_domain_score',
    y='Communities',
    #hue='Communities',
    data=bottom10,
    palette='Greens_d'
)
plt.title('Bottom 10 Communities by Economic Opportunity Score')
plt.xlabel('Economic Opportunity Score')
plt.ylabel('Community')
plt.tight_layout()
plt.show()

# --- Top 10 Communities ---
plt.figure(figsize=(12, 7))
sns.barplot(
    x='economic_opportunity_domain_score',
    y='Communities',
    #hue='Communities',
    data=top10,
    palette='Reds_d'
)
plt.title('Top 10 Communities by Economic Opportunity Score', fontsize = 14)
plt.xlabel('Economic Opportunity Score', fontsize = 12)
plt.ylabel('Community', fontsize = 12)
plt.tight_layout()
plt.show()

# %% [markdown]
# This ranks the Top and bottom 10 communities witn high and low economic opportunities.
# High Scores represents high level of Economic instablility and low scores represents low level of Economic instabilty.
#
# As coloured in green and red, the green shows the communities doing well Economically and Color red is the opposite.

# %% [markdown]
# **CONCLUSIONS:**
#
# **1)** NE Calgary is a hotspot for economic vulnerability, with the highest average unemployment and largest proportion of working poor — signaling a need for focused job creation and training programs.
#
# **2)** NW and SW Calgary lead in economic opportunity, showing stronger CEI scores and lower rates of poverty and unemployment — likely reflecting better infrastructure, services, and employment access.
#
# **3)** Core housing need is not limited to low-income communities — even some middle-income areas like Varsity face high housing stress, suggesting complex affordability issues beyond income levels.
#
# **4)** Communities with low housing need (e.g., Aspen Woods, Lake Bonavista) align with higher income and employment stability — useful benchmarks for policy planning.
#
# **5)** Market Basket Measure data revealed that several communities face concentrated poverty, emphasizing the need for localized policy interventions.

# %% [markdown]
# ## ACCESSIBILITY AND AMENITIES DOMAIN

# %%
## Query to find the top 5 communities by commute_vehicle_perc
query = """ 
SELECT Communities, commute_vehicle_perc
FROM CEI_table
ORDER BY commute_vehicle_perc DESC
LIMIT 5;
"""
df = pd.read_sql(query, engine)
print(df.head())


## Query to find the top 5 communities by commute_transit_perc
query = """
SELECT Communities, commute_transit_perc
FROM CEI_table
ORDER BY commute_transit_perc DESC
LIMIT 5;
"""
df = pd.read_sql(query, engine)
print(df.head())



## Query to find the 5 communities that have the highes commute_time
query = """
SELECT 
    Communities,
    average_commute_time,
    commute_transit_perc,
    commute_vehicle_perc
FROM 
    CEI_table
ORDER BY 
    average_commute_time DESC;
    """
df = pd.read_sql(query, engine)
print(df.head())


## Analyzing Spatial Disparities in Educational Accessibility
query = """
SELECT 
    Communities,
    spatial_access_primary_secondary_education_transit,
    children_perc,
    educ_no_cert_perc
FROM 
    CEI_table
ORDER BY 
    spatial_access_primary_secondary_education_transit DESC;
    """

df = pd.read_sql(query, engine)
print(df.head())
# Out:
#      Communities  commute_vehicle_perc
# 0  MEDICINE HILL                100.00
# 1  MCKENZIE LAKE                 94.16
# 2        TUSCANY                 94.14
# 3  MCKENZIE LAKE                 93.60
# 4  MCKENZIE LAKE                 93.39
#                                        Communities  commute_transit_perc
# 0             DOWNTOWN COMMERCIAL CORE, EAU CLAIRE                 29.77
# 1                                DOWNTOWN WEST END                 29.48
# 2  DOWNTOWN COMMERCIAL CORE, DOWNTOWN EAST VILLAGE                 27.67
# 3                                         SOMERSET                 25.97
# 4                                        BRENTWOOD                 22.27
#    Communities  average_commute_time  commute_transit_perc  \
# 0  ALPINE PARK                 30.57                  9.27
# 1     SOMERSET                 30.51                 25.97
# 2   NOLAN HILL                 30.51                  4.88
# ...

# %%
## Analyzing factors contributing to commute time differences between transit users and drivers

import matplotlib.pyplot as plt
import seaborn as sns

equity_df = pd.read_csv("2024_CEI_Data.csv")
query = """
SELECT average_commute_time, commute_transit_perc, commute_vehicle_perc
FROM CEI_table
"""
df = pd.read_sql(query, engine)

plt.figure(figsize=(12, 7))
sns.scatterplot(data=equity_df, x="commute_transit_perc", y="average_commute_time", label="Transit Users")
sns.scatterplot(data=equity_df, x="commute_vehicle_perc", y="average_commute_time", label="Drivers")
plt.title("Commute Time vs Transportation Mode", fontsize = 14)
plt.xlabel("Percentage of Mode Users", fontsize = 14)
plt.ylabel("Average Commute Time", fontsize = 14)
plt.legend()
plt.show()

# %% [markdown]
# **Observation**:<br>
# Analyzing commute times i.e average commute time, transit vs. vehicle percentages, reveals disparities in transportation choices and their impact on daily lives. it brings attention to equality in transportation infrastructure, including who gains and who loses, and providing suggestions for areas that need improvement.
#
# Transit Users are primarily clustered at the lower percentages (approximately 0-30%), indicating that fewer commuters rely on transit. Drivers are mainly concentrated at higher percentages (around 70-100%), suggesting that most commuters prefer driving as their primary mode of transportation. Transit Users generally experience longer commute times, with the cluster positioned higher, around 25-30 minutes. Drivers experience slightly shorter commute times, mostly clustered around 20-25 minutes . Overall, the chart indicates a clear division in commuting modes, where driving is the dominant choice among commuters. Transit users, while fewer, typically face slightly longer commute durations. The segregation in mode preference is stark, highlighting potential implications for transportation planning, infrastructure investment, and public transit policy considerations

# %%
## Highlighting how transportation choices vary depending on proximity to services.
parameters = [
    "proximity_healthcare", "proximity_grocerystores", 
    "proximity_library", "proximity_neighbourhood_parks"
]
query = f"""
SELECT {', '.join(parameters)}, commute_transit_perc, commute_vehicle_perc
FROM CEI_table
"""
df = pd.read_sql(query, engine)
data_melted = equity_df.melt(value_vars=parameters, 
                        id_vars=["commute_transit_perc", "commute_vehicle_perc"], 
                        var_name="Service", 
                        value_name="Proximity Score")

plt.figure(figsize=(12, 7))
sns.barplot(x="Service", y="Proximity Score", data=data_melted)
plt.title("Comparison of Proximity Scores Across Services")
plt.ylabel("Proximity Scores")
#plt.legend(title="Transit %")
plt.show()

# %% [markdown]
# **Observation**<br>
# The bar chart presents data on the proximity scores for different community services such as healthcare, grocery stores, libraries, and neighborhood parks, while also indicating the transit usage percentage (ranging from 0% to 25%).
#
# Healthcare has the highest variation and the greatest overall proximity scores among the four services. Scores are highly variable, with some communities showing very high proximity (above 0.7), while many others remain quite low (below 0.3). This suggests unequal distribution and access to healthcare facilities across communities.
#
# Neighborhood Parks exhibit consistently moderate proximity scores, suggesting generally reasonable accessibility across different communities. Grocery Stores display consistently lower proximity scores overall, implying limited accessibility to grocery stores in many areas.
#
# Libraries have the lowest overall proximity scores, indicating widespread limited access to library services across most communities.
#
# In summary, this visual underscores significant inequalities in spatial access to essential community services. Healthcare access is notably varied, with some communities exceptionally well-served while others lag considerably behind. Grocery stores and libraries suffer from overall low proximity scores, highlighting critical gaps in these essential resources. Neighborhood parks, in contrast, are the most evenly distributed resource.

# %%
# SQL query for top 10 communities
query = """
SELECT Communities, spatial_access_primary_secondary_education_transit, children_perc
FROM CEI_table
ORDER BY spatial_access_primary_secondary_education_transit DESC
LIMIT 10;
"""

# Load query results into a Pandas DataFrame
df = pd.read_sql(query, engine)

# Plotting the barplot using Seaborn
plt.figure(figsize=(12, 7))
sns.barplot(data=df, x="spatial_access_primary_secondary_education_transit", y="children_perc", hue="Communities", dodge=False)
plt.title("Spatial Access to Education vs Children Percentage", fontsize = 14)
plt.xlabel("Access to Primary & Secondary Education (Transit)", fontsize = 14)
plt.ylabel("Children Percentage", fontsize = 14)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation**:
# The bar chart compares several communities based on two dimensions: the percentage of children within each community and their accessibility to primary and secondary education via public transit.
#
# Rosedale, Sunnyside has the highest percentage of children (approximately 12%), substantially higher than all other communities, despite its higher children percentage, shows the lowest access (approximately 0.67), implying significant spatial limitations or challenges in accessing primary and secondary education by public transit.
#
# Cliff Bungalow has a moderate level, around 7%, followed by Beltline,
#
# Downtown Commercial Core (East Village), and other downtown neighborhoods with progressively lower percentages, typically ranging between 5% to 8% showws the highest accessibility scores (~0.81 to 0.84), indicating better transit access to education facilities
#
#
# Summary: There's a noticeable discrepancy in transit accessibility between neighborhoods with high percentages of children and neighborhoods offering good access to transit. Communities with more children (such as Rosedale, Sunnyside) are notably underserved regarding transit accessibility compared to downtown areas with fewer children.
# <br>
# <br>

# %% [markdown]
# **CONCLUSIONS**
# <br>
# Amenities and Proximity domain displays critical relationships between transportation modes, demographic distributions, and accessibility to essential services within communities in Calgary.Noteworthy findings include the pronounced disparity in commute times between transit users and drivers, suggesting inefficiencies in public transportation systems and over-dependence on private vehicles.
# <br>
# <br>
# Additionally, significant inequities were observed in spatial access to primary and secondary education, especially highlighting communities such as Rosedale and Sunnyside, where higher proportions of children ironically correlated with lower transit accessibility.
# <br>
# <br>
# Furthermore, the analysis of community proximity to vital resources revealed substantial variations. Healthcare access notably varied between neighborhoods, underscoring spatial inequalities in essential health services. Similarly, limited proximity to grocery stores and libraries further illustrated potential vulnerabilities in community infrastructure. Neighborhood parks, however, emerged as relatively equitably distributed services, suggesting a successful model for future planning initiatives. These findings emphasize persistent inequalities within urban environments concerning commute efficiency, educational accessibility, and proximity to essential services.
# <br>
# <br>

# %% [markdown]
# ## DISCUSSION

# %% [markdown]
# **Individual Learnings:** each team member gained valuable experience working with realworld dataset. We improved our SQL querying skills - querying across multiple domains to gain a deeper understanding of how social, health, economic and environmental data interact. We also recognized the importance of data cleaning and preprocessing to ensure meaningful analysis. We also refreshed/improved our data visualization skills.
#
# **Future Improvements:** Looking back, incorporating GIS mapping tools would have helped visualize geographic trends better. In future iterations, we aim to utilise advanced mapping tools and techniques to create filled maps to show the disparities in inequities more intuitively. Further, we have identified and understood the need to select variables more thoughtfully ensuring they align with the projects objectives and provide deeper insights. Overall, this project demonstrated the power of data querying, analysis and visualizing in revealing complex relationships across multiple domains, and it provided a strong foundation for us in sql querying to take on more advanced projects.

# %% [markdown]
# ## CONCLUSIONS/ KEY TAKEWAYS:
# **(1) Human and Social Wellbeing Needs:** Communities in NE suffer the highest inequities in Human and Social Wellbeing, reflecting high concentration of vulnerabale groups like recent immigrants, refugees, indigenous populations, single parent households headed by women and seniors living alone.
#
# **(2) Climate and Environment Domain:** While inequities in Climate and Environment domain persist across all quadrants, SW and NW fare better  overall. Some communities in Downtown communities and Eastern quadrants (NE and SE) struggle with issues such as less tree canopy and greater noise pollution especially downtown areas
#
# **(3) Economic Opportunity:** NE Calgary is an economic vulnerability hotspot, with highest unemployment rates and largest proportion of working poor. SW and NW quadrants lead in economic opportunity, showcasing better infrastructure, services and access to employment opportunities
#
# **(4) Population Health and Belonging:** A strong correlation exists between population health and community belonging scires, emphasizing the impact of social cohesion on health outcome. Communities with higher social disorder rates tend to exhibit poorer health and belonging scores.
#
# **(5) Accessibility and Amenities:** Significant needs exist in the Accessibility and Amenities domain across Calgary especially in SE, SW and NW quadrants. Critical issues include long commute times for transit users and limited spatial access to essential services like grocery stores and healthcare.
#
# **(6) Recommendations:**
# Targeted programs like language training, skill training etc to improve economic opportunities and reduce poverty in NE. Increase tree cover in NE and SE. Improve Calgary's public transit systems and access to primary/secondary education in underserved communities.

# %% [markdown]
# ## REFERENCES:
# [1] Calgary Open Data Portal
# <br>
# [2] Calgary equity index. https://www.calgary.ca. (n.d.).
# https://www.calgary.ca/research/calgary-equity-index.html
# <br>
# [3]Calgary, T. C. of. (2024, November 2). Calgary equity index - 2024: Open Calgary. data.calgary.ca.<br>
# https://data.calgary.ca/Demographics/Calgary-Equity-Index-2024/i6pu-a35d/about_data
# <br>
# [4]Calgary Equity Index - 2024
